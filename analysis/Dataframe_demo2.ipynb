# %% [markdown]
# # Modifying Dataframes

# %%
import pandas as pd
houses = pd.read_csv("kc_house_data.csv")
titanic = pd.read_csv("DataAnalysis/data/titanic.csv")
neflix = pd.read_csv("netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("coin_Bitcoin.csv")
countries = pd.read_csv("DataAnalysis/data/world-happiness-report-2021.csv")

# %%
countries.set_index("Country name", inplace=True)

# %% [markdown]
# ## Drop

# %%
btc.drop(labels="Symbol", axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
# btc.drop(labels=["SNo","Name","Symbol"], axis='columns')
btc.drop(columns=["SNo","Name","Symbol"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc[["Date", "High", "Low"]]
# Out:
#                      Date          High           Low
# 0     2013-04-29 23:59:59    147.488007    134.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003
# 2     2013-05-01 23:59:59    139.889999    107.720001
# 3     2013-05-02 23:59:59    125.599998     92.281898
# 4     2013-05-03 23:59:59    108.127998     79.099998
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169
#
# [2991 rows x 3 columns]

# %%
btc.drop(columns=["SNo","Name","Symbol"], inplace=True)

# %%
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(labels="Denmark", axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.drop(["Denmark", "Finland", "Iceland"], axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
btc.sort_index(ascending=False, inplace=True)
btc.drop(2990)
# Out:
#                      Date          High           Low          Open  \
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2985  2021-07-01 23:59:59  35035.982712  32883.781226  35035.982712
# ...                   ...           ...           ...           ...
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap
# 2989  33746.002456  2.672155e+10  6.326962e+11
# 2988  35287.779766  2.492431e+10  6.615748e+11
# ...

# %%
countries.drop(countries.index[10:])
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Finland              Western Europe         7.842
# Denmark              Western Europe         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway               Western Europe         7.392
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
titanic["species"] = "human"
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses.insert(0,"county","King county")

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King county  7129300520  20141013T000000  221900.0         3
# 1      King county  6414100192  20141209T000000  538000.0         3
# 2      King county  5631500400  20150225T000000  180000.0         2
# 3      King county  2487200875  20141209T000000  604000.0         4
# 4      King county  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King county   263000018  20140521T000000  360000.0         3
# 21609  King county  6600060120  20150223T000000  400000.0         4
# 21610  King county  1523300141  20140623T000000  402101.0         2
# 21611  King county   291310100  20150116T000000  400000.0         3
# 21612  King county  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses["sale_price"] = houses["price"]

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King county  7129300520  20141013T000000  221900.0         3
# 1      King county  6414100192  20141209T000000  538000.0         3
# 2      King county  5631500400  20150225T000000  180000.0         2
# 3      King county  2487200875  20141209T000000  604000.0         4
# 4      King county  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King county   263000018  20140521T000000  360000.0         3
# 21609  King county  6600060120  20150223T000000  400000.0         4
# 21610  King county  1523300141  20140623T000000  402101.0         2
# 21611  King county   291310100  20150116T000000  400000.0         3
# 21612  King county  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
houses.insert(3,"num_bedrooms",houses["bedrooms"])

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King county  7129300520  20141013T000000             3  221900.0
# 1      King county  6414100192  20141209T000000             3  538000.0
# 2      King county  5631500400  20150225T000000             2  180000.0
# 3      King county  2487200875  20141209T000000             4  604000.0
# 4      King county  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King county   263000018  20140521T000000             3  360000.0
# 21609  King county  6600060120  20150223T000000             4  400000.0
# 21610  King county  1523300141  20140623T000000             2  402101.0
# 21611  King county   291310100  20150116T000000             3  400000.0
# 21612  King county  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %%
titanic.drop(columns="species", inplace=True)

# %%
titanic["sibsp"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64

# %%
titanic.parch
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic["sibsp"] + titanic["parch"]
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic["num_relatives"] = titanic["sibsp"] + titanic["parch"]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values(by="num_relatives", ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic[titanic["survived"] == 1].sort_values(by="num_relatives", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
solo_passengers = titanic["num_relatives"] == 0
titanic[solo_passengers].sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='sex'>

# %%
titanic.sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='sex'>

# %%
houses["price_sqft"] = houses["price"] / houses["sqft_living"]

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King county  7129300520  20141013T000000             3  221900.0
# 1      King county  6414100192  20141209T000000             3  538000.0
# 2      King county  5631500400  20150225T000000             2  180000.0
# 3      King county  2487200875  20141209T000000             4  604000.0
# 4      King county  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King county   263000018  20140521T000000             3  360000.0
# 21609  King county  6600060120  20150223T000000             4  400000.0
# 21610  King county  1523300141  20140623T000000             2  402101.0
# 21611  King county   291310100  20150116T000000             3  400000.0
# 21612  King county  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values(by="price_sqft", ascending=False)
# Out:
#             county          id             date  num_bedrooms      price  \
# 19336  King county  6021500970  20150407T000000             2   874950.0
# 4013   King county   724069059  20140509T000000             3  2400000.0
# 10446  King county  1118000320  20150508T000000             4  3400000.0
# 8623   King county  6303400395  20150130T000000             1   325000.0
# 9314   King county  4389200610  20141201T000000             2   903000.0
# ...            ...         ...              ...           ...        ...
# 1385   King county  3342700465  20150123T000000             3   250000.0
# 17197  King county  5111400086  20140512T000000             3   110000.0
# 13825  King county  5637200450  20141017T000000             5   257000.0
# 3785   King county   723049156  20140523T000000             3   149000.0
# 18262  King county  2891000610  20141211T000000             4   148900.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values(by="price_sqft", ascending=False).head(50)["zipcode"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
btc.set_index("Date")
# Out:
#                              High           Low          Open         Close  \
# Date
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# ...                           ...           ...           ...           ...
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
#
#                            Volume     Marketcap
# ...

# %%
btc["change"] = btc["Close"] - btc["Open"]

# %%
btc
# Out:
#                      Date          High           Low          Open  \
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap       change
# 2990  34235.193451  2.650126e+10  6.418992e+11   511.683796
# ...

# %%
btc.sort_values("change", ascending=False)
# Out:
#                      Date          High           Low          Open  \
# 2842  2021-02-08 23:59:59  46203.931437  38076.322807  38886.827290
# 2919  2021-04-26 23:59:59  54288.002155  48852.796843  49077.792363
# 2863  2021-03-01 23:59:59  49784.015290  45115.093115  45159.503053
# 2853  2021-02-19 23:59:59  56113.650547  50937.275722  51675.981285
# 2923  2021-04-30 23:59:59  57900.719988  53129.600877  53568.663584
# ...                   ...           ...           ...           ...
# 2911  2021-04-18 23:59:59  61057.456509  52829.535926  60701.886093
# 2824  2021-01-21 23:59:59  35552.679497  30250.749639  35549.397409
# 2857  2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756
# 2942  2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447
# 2935  2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167
#
#              Close        Volume     Marketcap       change
# 2842  46196.463719  1.014672e+11  8.603427e+11  7309.636429
# ...

# %%
btc["delta"] = btc["High"] - btc["Low"]

# %%
btc
# Out:
#                      Date          High           Low          Open  \
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap       change        delta
# 2990  34235.193451  2.650126e+10  6.418992e+11   511.683796  1438.620194
# ...

# %%
btc.sort_values("delta", ascending=False)
# Out:
#                      Date          High           Low          Open  \
# 2942  2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447
# 2857  2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756
# 2935  2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167
# 2856  2021-02-22 23:59:59  57533.389325  48967.565188  57532.738864
# 2944  2021-05-21 23:59:59  42172.173616  33616.453884  40596.948323
# ...                   ...           ...           ...           ...
# 871   2015-09-17 23:59:59    230.285004    228.925995    229.076004
# 768   2015-06-06 23:59:59    225.718994    224.378998    225.005005
# 759   2015-05-28 23:59:59    237.824005    236.651993    237.257004
# 888   2015-10-04 23:59:59    238.968002    237.940002    238.531006
# 100   2013-08-07 23:59:59    106.750000    106.750000    106.750000
#
#              Close        Volume     Marketcap       change         delta
# 2942  37002.440466  1.263581e+11  6.924526e+11 -5942.534981  12864.619573
# ...

# %%
btc.set_index("Date", inplace=True)

# %%
btc.sort_values("delta", ascending=False).head(10)["delta"].plot(kind="bar")
# Out:
# <Axes: xlabel='Date'>

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {"Regional indicator": "regional_indicator", "Ladder score": "ladder_score"}
countries.rename(columns=mapper, inplace=True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {"Finland": "finland", "Denmark": "denmark"}
countries.rename(index=mapper)
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
# #  The Replace Method

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"].replace("female", "F", inplace=True)

# %%
titanic["sex"].replace("F", "female", inplace=True)

# %%
titanic["sex"].replace(["female","male"], ["F","M"])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
import pandas as pd
titanic = pd.read_csv("DataAnalysis/data/titanic.csv")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["age"].replace("?","idk").value_counts()
# Out:
# idk       263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic["age"].replace("?",None).value_counts()
# Out:
# 24        47
# 22        43
# 21        41
# 30        40
# 18        39
#           ..
# 0.3333     1
# 22.5       1
# 70.5       1
# 0.6667     1
# 26.5       1
# Name: age, Length: 98, dtype: int64

# %%
titanic["age"].replace(["?"],[None]).value_counts(dropna=False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic["age"].replace(["?"],[None], inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
countries.loc["Brazil" : "Cambodia"]
# Out:
#                               regional_indicator  ladder_score  \
# Country name
# Brazil               Latin America and Caribbean         6.330
# Mexico               Latin America and Caribbean         6.317
# Jamaica              Latin America and Caribbean         6.309
# Lithuania             Central and Eastern Europe         6.255
# Cyprus                            Western Europe         6.223
# ...                                          ...           ...
# Ukraine       Commonwealth of Independent States         4.875
# Iraq                Middle East and North Africa         4.854
# Gabon                         Sub-Saharan Africa         4.852
# Burkina Faso                  Sub-Saharan Africa         4.834
# Cambodia                          Southeast Asia         4.830
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# ...

# %%
countries.loc["Brazil", ["ladder_score", "Healthy life expectancy"]]
# Out:
# ladder_score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[["Costa Rica", "Panama", "Honduras"], ["ladder_score", "Healthy life expectancy"]]
# Out:
#               ladder_score  Healthy life expectancy
# Country name
# Costa Rica           7.069                   71.400
# Panama               6.180                   69.652
# Honduras             5.919                   67.300

# %%
countries.loc[["Denmark", "Sweden", "Norway"], ["regional_indicator"]]
# Out:
#              regional_indicator
# Country name
# Denmark          Western Europe
# Sweden           Western Europe
# Norway           Western Europe

# %%
countries.loc[["Denmark", "Sweden", "Norway"], ["regional_indicator"]] = "Scandinavia"

# %%
countries.head(10)
# Out:
#                  regional_indicator  ladder_score  \
# Country name
# Finland              Western Europe         7.842
# Denmark                 Scandinavia         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway                  Scandinavia         7.392
# Sweden                  Scandinavia         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.loc["Finland"] = "LOL"

# %%
countries.loc["Finland", ["upperwhisker", "lowerwhisker"]] = "MEOW"

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                      LOL          LOL                            LOL
# Denmark              Scandinavia         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Norway", "Sweden"]]
# Out:
#              regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                     LOL          LOL                            LOL
# Denmark             Scandinavia         7.62                          0.035
# Iceland          Western Europe        7.554                          0.059
# Norway              Scandinavia        7.392                          0.035
# Sweden              Scandinavia        7.363                          0.036
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# Finland              MEOW         MEOW                   LOL            LOL
# Denmark             7.687        7.552                10.933          0.954
# Iceland              7.67        7.438                10.878          0.983
# Norway              7.462        7.323                11.053          0.954
# Sweden              7.433        7.293                10.867          0.934
#
# ...

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Norway", "Sweden"], ['regional_indicator', 'isCold']] = "dogs!!!"

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Norway", "Sweden"]]
# Out:
#              regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                 dogs!!!          LOL                            LOL
# Denmark                 dogs!!!         7.62                          0.035
# Iceland                 dogs!!!        7.554                          0.059
# Norway                  dogs!!!        7.392                          0.035
# Sweden                  dogs!!!        7.363                          0.036
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# Finland              MEOW         MEOW                   LOL            LOL
# Denmark             7.687        7.552                10.933          0.954
# Iceland              7.67        7.438                10.878          0.983
# Norway              7.462        7.323                11.053          0.954
# Sweden              7.433        7.293                10.867          0.934
#
# ...

# %%
countries.loc[["Finland", "Denmark", "Iceland", "Norway", "Sweden"], ['regional_indicator', 'isCold']] = ["Nordic Countries", "yes!"]

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland         Nordic Countries          LOL                            LOL
# Denmark         Nordic Countries         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland         Nordic Countries        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
many_bedrooms = houses["bedrooms"] >= 10

# %%
houses.loc[many_bedrooms, ['bedrooms']]
# Out:
#        bedrooms
# 8757         11
# 13314        10
# 15161        10
# 15870        33
# 19254        10

# %%
 houses.loc[many_bedrooms, ['bedrooms']] = "TOO MAN!"

# %%
houses[many_bedrooms]
# Out:
#             county          id             date  num_bedrooms      price  \
# 8757   King county  1773100755  20140821T000000            11   520000.0
# 13314  King county   627300145  20140814T000000            10  1148000.0
# 15161  King county  5566100170  20141029T000000            10   650000.0
# 15870  King county  2402100895  20140625T000000            33   640000.0
# 19254  King county  8812401450  20141229T000000            10   660000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# 8757   TOO MAN!       3.00         3000      4960     2.0  ...            600
# 13314  TOO MAN!       5.25         4590     10920     1.0  ...           2090
# 15161  TOO MAN!       2.00         3610     11914     2.0  ...            600
# 15870  TOO MAN!       1.75         1620      6000     1.0  ...            580
# 19254  TOO MAN!       3.00         2920      3745     2.0  ...           1060
#
# ...

# %%
high_quality = houses["grade"] > 12
great_views = houses["view"] == 4
houses[high_quality & great_views]
# Out:
#             county          id             date  num_bedrooms      price  \
# 9254   King county  9208900037  20140919T000000             6  6885000.0
# 14556  King county  2303900035  20140611T000000             5  2888000.0
# 19017  King county  2303900100  20140911T000000             3  3800000.0
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# 9254         6       7.75         9890     31374     2.0  ...           1030
# 14556        5       6.25         8670     64033     2.0  ...           2550
# 19017        3       4.25         5510     35000     2.0  ...            600
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 9254       2001             0    98039  47.6305 -122.240           4540
# 14556      1965          2003    98177  47.7295 -122.372           4140
# 19017      1997             0    98177  47.7296 -122.370           3430
#
#        sqft_lot15  sale_price  price_sqft
# ...

# %%
houses['luxury_level'] = "normal"

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King county  7129300520  20141013T000000             3  221900.0
# 1      King county  6414100192  20141209T000000             3  538000.0
# 2      King county  5631500400  20150225T000000             2  180000.0
# 3      King county  2487200875  20141209T000000             4  604000.0
# 4      King county  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King county   263000018  20140521T000000             3  360000.0
# 21609  King county  6600060120  20150223T000000             4  400000.0
# 21610  King county  1523300141  20140623T000000             2  402101.0
# 21611  King county   291310100  20150116T000000             3  400000.0
# 21612  King county  1523300157  20141015T000000             2  325000.0
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  yr_built  \
# ...

# %%
houses.loc[high_quality & great_views, ['luxury_level']] = "ultra"

# %%
houses["luxury_level"].value_counts()
# Out:
# normal    21610
# ultra         3
# Name: luxury_level, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic["age"].value_counts()
# Out:
# 24        47
# 22        43
# 21        41
# 30        40
# 18        39
#           ..
# 0.3333     1
# 22.5       1
# 70.5       1
# 0.6667     1
# 26.5       1
# Name: age, Length: 98, dtype: int64

# %%
titanic["age"].replace(['?'], [None], inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic["age"].astype("float")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic["age_float"] = titanic["age"].astype("float")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ### ASTYPE METHOD

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 153.5+ KB

# %%
titanic["age"] = titanic["age"].astype("float")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 153.5+ KB

# %%
titanic["age"].mean()
# Out:
# 29.8811345124283

# %%
titanic["sex"].astype("category")
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: category
# Categories (2, object): ['female', 'male']

# %%
titanic["sex"] = titanic["sex"].astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   category
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: category(1), float64(2), int64(4), object(8)
# memory usage: 144.7+ KB

# %%
titanic["sex"] = "MALE"

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 153.5+ KB

# %%
titanic["embarked"] = titanic["embarked"].astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   category
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: category(1), float64(2), int64(4), object(8)
# memory usage: 144.8+ KB

# %% [markdown]
# ### TO_NUMERIC Method

# %%
titanic = pd.read_csv("DataAnalysis/data/titanic.csv")
titanic["age"].value_counts()
# Out:
# ?         263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
pd.to_numeric(titanic["age"], errors="coerce")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
titanic["age"].describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %% [markdown]
# ### ISNA, DROPNA, FILLNA

# %%
stats = pd.read_csv("DataAnalysis/data/game_stats.csv")

# %%
stats
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN         NaN     NaN      NaN       NaN

# %%
stats.isna()
# Out:
#     name  league  points  assists  rebounds
# 0  False   False   False    False     False
# 1  False    True   False     True     False
# 2  False   False    True     True      True
# 3  False   False   False     True     False
# 4  False    True   False     True      True
# 5  False   False   False    False     False
# 6   True    True    True     True      True

# %%
stats.isnull()
# Out:
#     name  league  points  assists  rebounds
# 0  False   False   False    False     False
# 1  False    True   False     True     False
# 2  False   False    True     True      True
# 3  False   False   False     True     False
# 4  False    True   False     True      True
# 5  False   False   False    False     False
# 6   True    True    True     True      True

# %%
stats[stats["league"].isna()]
# Out:
#        name league  points  assists  rebounds
# 1    jessie    NaN    10.0      NaN       2.0
# 4  timothee    NaN     8.0      NaN       NaN
# 6       NaN    NaN     NaN      NaN       NaN

# %%
stats["assists"].dropna()
# Out:
# 0    5.0
# 5    8.0
# Name: assists, dtype: float64

# %%
assists = stats["assists"]
assists.dropna(inplace=True)

# %%
assists
# Out:
# 0    5.0
# 5    8.0
# Name: assists, dtype: float64

# %%
stats.dropna()
# Out:
#     name league  points  assists  rebounds
# 0    bob    nba    22.0      5.0      10.0
# 5  steph    nba    49.0      8.0      10.0

# %%
stats
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN         NaN     NaN      NaN       NaN

# %%
stats = pd.read_csv("DataAnalysis/data/game_stats.csv")
stats
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN         NaN     NaN      NaN       NaN

# %%
stats.dropna(how="all")
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0

# %%
stats.dropna(subset=["league", "points"])
# Out:
#       name league  points  assists  rebounds
# 0      bob    nba    22.0      5.0      10.0
# 3  jackson    aba     9.0      NaN       2.0
# 5    steph    nba    49.0      8.0      10.0

# %%
stats.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
stats
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN         NaN     NaN      NaN       NaN

# %%
stats.fillna(0)
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie           0    10.0      0.0       2.0
# 2       stu  euroleague     0.0      0.0       0.0
# 3   jackson         aba     9.0      0.0       2.0
# 4  timothee           0     8.0      0.0       0.0
# 5     steph         nba    49.0      8.0      10.0
# 6         0           0     0.0      0.0       0.0

# %%
stats["league"].fillna("amateur", inplace=True)

# %%
stats.fillna({"points":0, "assists": "None"})
# Out:
#        name      league  points assists  rebounds
# 0       bob         nba    22.0     5.0      10.0
# 1    jessie     amateur    10.0    None       2.0
# 2       stu  euroleague     0.0    None       NaN
# 3   jackson         aba     9.0    None       2.0
# 4  timothee     amateur     8.0    None       NaN
# 5     steph         nba    49.0     8.0      10.0
# 6       NaN     amateur     0.0    None       NaN

# %%
sales = pd.read_csv("DataAnalysis/data/sales.csv")

# %%
sales
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0           NaN      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0           NaN      92660.0
# 5     NaN           NaN          NaN
# 6     NaN       60007.0      60007.0

# %%
sales["shipping_zip"].fillna(sales["billing_zip"],inplace=True)

# %%
sales
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0       81220.0      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0       92660.0      92660.0
# 5     NaN           NaN          NaN
# 6     NaN       60007.0      60007.0

# %% [markdown]
# ## WORKING WITH DATES AND TIMES

# %%
charts = pd.read_csv("DataAnalysis/data/billboard_charts.csv", parse_dates=["date"])
ufos = pd.read_csv("DataAnalysis/data/nuforc_reports.csv")

# %%
pd.to_datetime ("2019-12-31")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime ("2019/12/31")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime ("December 31st 2019")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime ("December 31st 2019 4pm")
# Out:
# Timestamp('2019-12-31 16:00:00')

# %%
pd.to_datetime ("Dec. 25 1990 12:30pm")
# Out:
# Timestamp('1990-12-25 12:30:00')

# %%
pd.to_datetime ("3:55:45 Apr. 2nd 90")
# Out:
# Timestamp('1990-04-02 03:55:45')

# %%
dates = ["3:55:45 Apr. 2nd 90", "3:55:45 Apr. 22nd 90", "7:55:45 Jan. 2nd 90"]
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['1990-04-02 03:55:45', '1990-04-22 03:55:45',
#                '1990-01-02 07:55:45'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime("10/11/12")
# Out:
# Timestamp('2012-10-11 00:00:00')

# %%
pd.to_datetime("10/11/12", dayfirst=True)
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime("10/11/12", yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime("10/11/12", yearfirst=True,  dayfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
pd.to_datetime("10/11/12", format="%y/%m/%d")
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
meetings = ["Dec 11 2019 Meeting", "jan 6 2020 Meeting", "Mar 19 2020 Meeting", "Apr 15 2020 Meeting"]

# %%
pd.to_datetime(meetings, format="%b %d %Y Meeting")
# Out:
# DatetimeIndex(['2019-12-11', '2020-01-06', '2020-03-19', '2020-04-15'], dtype='datetime64[ns]', freq=None)

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 8.1+ MB

# %%
pd.to_datetime(ufos["date_time"])
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
pd.to_datetime(ufos["date_time"])

# %%
ufos["date"] = pd.to_datetime(ufos["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 8.7+ MB

# %%
ufos.tail()
# Out:
#                                                  summary            city  \
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape    duration  \
# 88120    AZ  2019-10-02T20:00:00  formation   3 minutes
# 88121    MO  2019-10-02T20:00:00      light  20 seconds
# 88122    FL  2019-10-02T20:03:00  formation  20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball   2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere   3 minutes
#
#                                                    stats  \
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# ...

# %%
ufos["date-time"] = pd.to_datetime(ufos["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
#  13  date-time       86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(10)
# memory usage: 9.4+ MB

# %%
ufos = pd.read_csv("DataAnalysis/data/nuforc_reports.csv", parse_dates=["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos["date_time"].dt.year.value_counts()
# Out:
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: date_time, dtype: int64

# %%
ufos["date_time"].dt.year.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
ufos["date_time"].dt.month.value_counts()
# Out:
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 6.0      8357
# 11.0     7596
# 12.0     6525
# 5.0      6063
# 1.0      5979
# 4.0      5817
# 3.0      5494
# 2.0      4559
# Name: date_time, dtype: int64

# %%
ufos["date_time"].dt.day
# Out:
# 0        12.0
# 1        22.0
# 2         NaN
# 3        17.0
# 4        15.0
#          ...
# 88120     2.0
# 88121     2.0
# 88122     2.0
# 88123     2.0
# 88124     2.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos["date_time"].dt.hour.value_counts()
# Out:
# 21.0    12851
# 22.0    11660
# 20.0     9565
# 23.0     8194
# 19.0     6460
# 0.0      5577
# 18.0     4462
# 1.0      3285
# 17.0     2660
# 2.0      2216
# 3.0      2088
# 5.0      1874
# 4.0      1641
# 16.0     1612
# 6.0      1588
# 12.0     1408
# 15.0     1380
# 10.0     1334
# 13.0     1308
# 11.0     1301
# 14.0     1280
# 9.0      1126
# 7.0      1067
# 8.0      1001
# Name: date_time, dtype: int64

# %%
ufos["date_time"].dt.hour.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
ufos["date_time"].dt.dayofweek.value_counts()
# Out:
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: date_time, dtype: int64

# %%
ufos["date_time"]
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos[ufos["date_time"] < "1980"]
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufos[ufos["date_time"] > "2019-12-23"]
# Out:
#                                                  summary        city state  \
# 85714  7-8 elongated objects flying in straight line ...  Wilmington    NC
#
#                 date_time  shape    duration  \
# 85714 2019-12-29 20:40:00  cigar  10 seconds
#
#                                                    stats  \
# 85714  Occurred : 11/29/2019 20:40  (Entered as : 12/...
#
#                                              report_link  \
# 85714  http://www.nuforc.org/webreports/151/S151158.html
#
#                                                     text               posted  \
# 85714  7-8 elongated objects flying in straight line ...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 85714      34.238375      -77.878468

# %%
ufos[ufos["date_time"].dt.hour ==2.0].head()
# Out:
#                                                summary         city state  \
# 3    I was driving towards the intersection of fall...       Ottawa    ON
# 14   Bright Circle of Light followed me from Oskalo...  Centerville    IA
# 148                              Strange Vibrations...    Indianola    IA
# 153  red ball ufo following small plane in tracy, c...        Tracy    CA
# 181  Silver disk flies through sky making zigzaggin...    Beaverton    OR
#
#               date_time     shape     duration  \
# 3   2019-04-17 02:00:00  teardrop   10 seconds
# 14  1999-08-15 02:30:00    circle       1 hour
# 148 1992-04-30 02:00:00   unknown    5 Minutes
# 153 1993-06-15 02:00:00     light    3 minutes
# 181 2015-04-16 02:30:00      disk  5-8 minutes
#
#                                                  stats  \
# 3    Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 14   Occurred : 8/15/1999 02:30  (Entered as : 08/1...
# 148  Occurred : 4/30/1992 02:00  (Entered as : 04/3...
# ...

# %%
ufos[ufos["date_time"].between("1988", "1989")].sort_values("date_time")
# Out:
#                                                  summary             city  \
# 4128   fast moving Triangle with no sound and orange ...          Roselle
# 8389   Gigantic circular object hovering, and then wi...           Kenner
# 2071   Broad daylight gold colored flying object abou...  New Britain Twp
# 33511  A dull yellow light, low off the ground and no...    Williamsfield
# 16295  8 gliding craft in formation with a 9th "quant...        Cambridge
# ...                                                  ...              ...
# 82524  Very bright light moving from South to North, ...        Dry Creek
# 21938  large saucer shaped object with many colored l...           Dexter
# 8808   Black huge triangle craft with chevron shape o...         Stockton
# 4363   saw 5 objects doing amazing manuevers for 20 m...       Alamogordo
# 61675  Hi 3 of us were out joy riding in our small ky...           Aurora
#
#       state           date_time     shape        duration  \
# ...

# %%
ufos[ufos["date_time"] > "2019-12-22"]
# Out:
#                                                  summary  \
# 3892   Lights in a row.  ((NUFORC Note:  Starlink sat...
# 3893   I saw a very big circle like thing in the sky ...
# 3894   I saw and photographed an object hovering abou...
# 3895   I stepped out back and saw a straight line pro...
# 3896   string of lights evenly spaced moving across s...
# 3897   satellite like looking objects single file lin...
# 3898   OBJECTS APPEAR AS SATELLITES IN FORMATION.  ((...
# 3899   31 UFOs seen traveling SW to NE in a mostly ev...
# 3900   Lights in sky in straight line at satellite he...
# 3901   The objects looked very high altitude.  ((Star...
# 3902   There was a line of very noticeable lights  tr...
# 3903   8 lights flying S to  equal distance from each...
# 3904   The event was already occurring when I became ...
# 3905   As I stood on my balcony, I saw approximately ...
# 3906   String of white lights that disappeared into a...
# ...

# %%
ufos["date_time"].value_counts()
# Out:
# 2015-11-07 18:00:00    104
# 2014-07-04 22:00:00     46
# 2010-07-04 22:00:00     37
# 2012-07-04 22:00:00     34
# 2015-07-04 22:00:00     27
#                       ...
# 2011-07-23 23:20:00      1
# 2011-07-23 23:47:00      1
# 2011-07-24 00:00:00      1
# 2011-07-24 00:02:00      1
# 2019-12-12 18:43:00      1
# Name: date_time, Length: 73122, dtype: int64

# %%
ufos["date_time"].dt.date.value_counts()
# Out:
# 2015-11-07    290
# 2014-07-04    270
# 2010-07-04    210
# 2012-07-04    200
# 2013-07-04    185
#              ...
# 1980-09-12      1
# 1988-06-13      1
# 1981-07-29      1
# 2004-07-04      1
# 2003-09-07      1
# Name: date_time, Length: 8351, dtype: int64

# %%
recent_sightings = ufos[ufos["date_time"].dt.year >=2018]
recent_sightings["date_time"].dt.date.value_counts()
# Out:
# 2019-11-11    77
# 2019-05-25    69
# 2019-05-26    67
# 2019-05-24    60
# 2019-07-04    57
#               ..
# 2019-12-29     1
# 2018-02-08     1
# 2019-05-09     1
# 2018-02-04     1
# 2018-02-07     1
# Name: date_time, Length: 719, dtype: int64

# %%
ufos[ufos["date_time"].between("2019-05-24", "2019-05-26")]
# Out:
#                                                 summary               city  \
# 1913  Were looking up at the stars and a string of w...         Fort Yates
# 1914  May 24th at approximately 0002 hours I witness...        Wilsonville
# 1915  30 white orbs.  ((NUFORC Note:  Satellites fro...           Mitchell
# 1916  seen a rip in the night sky.it looks like a br...        Hazel green
# 1917  It was somewhat a slow moving blurry light obj...           Staunton
# ...                                                 ...                ...
# 2521           Intense Bright Flashes for Four Hours...             Hulett
# 2581  We were outside, 11:54pm, saw 4 lights moving ...       Ocean Shores
# 2582  Reported seeing a triangle of lights, moving a...  Manitowish waters
# 2583  Formation of lights grows larger and passes ab...             Grants
# 2584  Huge 3 light UFO in night sky,  5/26/19.  ((an...          East Troy
#
#      state           date_time      shape    duration  \
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos["posted"] = pd.to_datetime(ufos["posted"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
ufos["posted"] - ufos["date_time"]
# Out:
# 0          9 days 05:17:00
# 1          6 days 05:30:00
# 2                      NaT
# 3          0 days 22:00:00
# 4       3685 days 06:00:00
#                ...
# 88120      1 days 04:00:00
# 88121      1 days 04:00:00
# 88122      1 days 03:57:00
# 88123      1 days 02:00:00
# 88124      1 days 02:00:00
# Length: 88125, dtype: timedelta64[ns]

# %%
ufos["time_before_reported"] = ufos["posted"] - ufos["date_time"]

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
longest_wait = ufos.sort_values("time_before_reported", ascending=False).head(10)

# %%
longest_wait["time_before_reported"].dt.days / 365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: time_before_reported, dtype: float64

# %%
longest_wait["time_before_reported"].dt.days
# Out:
# 86762    18463
# 87145    18353
# 721      18314
# 1576     18287
# 1580     18240
# 84984    18099
# 83965    17963
# 722      17951
# 723      17904
# 1301     17873
# Name: time_before_reported, dtype: int64

# %%
ufos["days_before_reporting"] = ufos["time_before_reported"].dt.days

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
charts["artist"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
number_1s = charts["rank"] == 1
charts[number_1s]["artist"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
charts[number_1s]["song"].value_counts()
# Out:
# Old Town Road                               19
# Despacito                                   16
# One Sweet Day                               16
# Rockstar                                    15
# I'll Make Love To You                       14
#                                             ..
# Then Came You                                1
# You Haven't Done Nothin                      1
# You Ain't Seen Nothing Yet/Free Wheelin'     1
# Whatever Gets You Thru The Night             1
# I'll Take You There                          1
# Name: song, Length: 1104, dtype: int64

# %%
p = charts[charts["song"] == "Old Town Road"].set_index("date")["rank"].plot()
p.invert_yaxis()
