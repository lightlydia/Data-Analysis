# %%
import pandas as pd

# %%
states = pd.read_csv("states.csv")
states
# Out:
#                    State Abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
houses = pd.read_csv("kc_house_data.csv")

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
type(houses)
# Out:
# pandas.core.frame.DataFrame

# %%
houses.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
states.columns
# Out:
# Index(['State', 'Abbreviation'], dtype='object')

# %%
len(houses)
# Out:
# 21613

# %%
houses.shape
# Out:
# (21613, 21)

# %%
houses.size
# Out:
# 453873

# %%
pd.options.display.min_rows = 15

# %%
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# ...           ...              ...        ...       ...        ...
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# ...

# %%
first_5 = houses.head()
first_5
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
type(first_5)
# Out:
# pandas.core.frame.DataFrame

# %%
houses.head (200)
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 0    7129300520  20141013T000000   221900.0         3       1.00         1180
# 1    6414100192  20141209T000000   538000.0         3       2.25         2570
# 2    5631500400  20150225T000000   180000.0         2       1.00          770
# 3    2487200875  20141209T000000   604000.0         4       3.00         1960
# 4    1954400510  20150218T000000   510000.0         3       2.00         1680
# 5    7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6    1321400060  20140627T000000   257500.0         3       2.25         1715
# ..          ...              ...        ...       ...        ...          ...
# 193  3663500060  20140625T000000   400000.0         3       2.50         2180
# 194  3996900125  20141201T000000   230000.0         3       1.00         1060
# 195  7796450200  20140515T000000   256883.0         3       2.50         1690
# ...

# %%
houses.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0              0      2009             0    98103  47.6993
# ...

# %%
houses.tail(9)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21604         1490      1126     3.0           0     0  ...      8
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         51 non-null     object
#  1   Abbreviation  51 non-null     object
# dtypes: object(2)
# memory usage: 944.0+ bytes

# %%
houses.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
titanic=pd.read_csv("tested.csv.xls")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
netflix=pd.read_csv("./netflix_titles.csv", sep="|",index_col=0)

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
pd.read_csv("2019_Census_US_Population_Data_By_State_Lat_Long.csv",names=["State","Population","Latitude","Longitude"])
pd.read_csv("2019_Census_US_Population_Data_By_State_Lat_Long.csv",)
# Out:
#                    STATE  POPESTIMATE2019        lat        long
# 0                Alabama          4903185  32.377716  -86.300568
# 1                 Alaska           731545  58.301598 -134.420212
# 2                Arizona          7278717  33.448143 -112.096962
# 3               Arkansas          3017804  34.746613  -92.288986
# 4             California         39512223  38.576668 -121.493629
# 5               Colorado          5758736  39.739227 -104.984856
# 6            Connecticut          3565287  41.764046  -72.682198
# 7               Delaware           973764  39.157307  -75.519722
# 8   District of Columbia           705749  38.895110  -77.036370
# 9                Florida         21477737  30.438118  -84.281296
# 10               Georgia         10617423  33.749027  -84.388229
# 11                Hawaii          1415872  21.307442 -157.857376
# 12                 Idaho          1787065  43.617775 -116.199722
# ...

# %% [markdown]
# ## Basic Dataframe Analysis
# - sum
# - min
# - max
# - median
# - mode
# - mean
# - count
# - describe

# %%
import pandas as pd 
houses = pd.read_csv("kc_house_data.csv")
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# ...           ...              ...        ...       ...        ...
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# ...

# %%
houses.min()
# Out:
# id                       1000102
# date             20140502T000000
# price                    75000.0
# bedrooms                       0
# bathrooms                    0.0
# sqft_living                  290
# sqft_lot                     520
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      1
# grade                          1
# sqft_above                 290.0
# sqft_basement                  0
# yr_built                    1900
# yr_renovated                   0
# zipcode                    98001
# lat                      47.1559
# long                    -122.519
# sqft_living15                399
# sqft_lot15                   651
# dtype: object

# %%
houses.max()
# Out:
# id                    9900000190
# date             20150527T000000
# price                  7700000.0
# bedrooms                      33
# bathrooms                    8.0
# sqft_living                13540
# sqft_lot                 1651359
# floors                       3.5
# waterfront                     1
# view                           4
# condition                      5
# grade                         13
# sqft_above                9410.0
# sqft_basement               4820
# yr_built                    2015
# yr_renovated                2015
# zipcode                    98199
# lat                      47.7776
# long                    -121.315
# sqft_living15               6210
# sqft_lot15                871200
# dtype: object

# %%
type(houses.max())
# Out:
# pandas.core.series.Series

# %%
houses.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                              38649028.0
# sqft_basement                                              6300385
# ...

# %%
houses.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.864903e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
titanic=pd.read_csv("tested.csv.xls")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.sum()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_1079/2139790256.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.sum()
# PassengerId                                               460009
# Survived                                                     152
# Pclass                                                       947
# Name           Kelly, Mr. JamesWilkes, Mrs. James (Ellen Need...
# Sex            malefemalemalemalefemalemalefemalemalefemalema...
# Age                                                      10050.5
# SibSp                                                        187
# Parch                                                        164
# Ticket         3309113632722402763151543101298753833097224873...
# Fare                                                  14856.5376
# ...

# %%
titanic.shape
# Out:
# (418, 12)

# %%
titanic.sum(numeric_only=True)
# Out:
# PassengerId    460009.0000
# Survived          152.0000
# Pclass            947.0000
# Age             10050.5000
# SibSp             187.0000
# Parch             164.0000
# Fare            14856.5376
# dtype: float64

# %%
pd.read_csv("2019_Census_US_Population_Data_By_State_Lat_Long.csv",names=["State","Population","Latitude","Longitude"])
states = pd.read_csv("2019_Census_US_Population_Data_By_State_Lat_Long.csv",)
states
# Out:
#                    STATE  POPESTIMATE2019        lat        long
# 0                Alabama          4903185  32.377716  -86.300568
# 1                 Alaska           731545  58.301598 -134.420212
# 2                Arizona          7278717  33.448143 -112.096962
# 3               Arkansas          3017804  34.746613  -92.288986
# 4             California         39512223  38.576668 -121.493629
# 5               Colorado          5758736  39.739227 -104.984856
# 6            Connecticut          3565287  41.764046  -72.682198
# 7               Delaware           973764  39.157307  -75.519722
# 8   District of Columbia           705749  38.895110  -77.036370
# 9                Florida         21477737  30.438118  -84.281296
# 10               Georgia         10617423  33.749027  -84.388229
# 11                Hawaii          1415872  21.307442 -157.857376
# 12                 Idaho          1787065  43.617775 -116.199722
# ...

# %%
states.tail(50). head(51).sum(numeric_only=True)
# Out:
# POPESTIMATE2019    3.233363e+08
# lat                1.977189e+03
# long              -4.664033e+03
# dtype: float64

# %%
titanic.count()
# Out:
# PassengerId    418
# Survived       418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
netflix=pd.read_csv("./netflix_titles.csv", sep="|",index_col=0)

# %%
netflix.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %% [markdown]
# ## Basic Dataframe Analysis
# - sum
# - min
# - max
# - median
# - mode
# - mean
# - count
# - describe

# %%
import pandas as pd
house=pd.read_csv("kc_house_data.csv")

# %%
house.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                              38649028.0
# sqft_basement                                              6300385
# ...

# %%
house.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.864903e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
titanic=pd.read_csv("tested.csv.xls")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.sum()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_1079/2139790256.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.sum()
# PassengerId                                               460009
# Survived                                                     152
# Pclass                                                       947
# Name           Kelly, Mr. JamesWilkes, Mrs. James (Ellen Need...
# Sex            malefemalemalemalefemalemalefemalemalefemalema...
# Age                                                      10050.5
# SibSp                                                        187
# Parch                                                        164
# Ticket         3309113632722402763151543101298753833097224873...
# Fare                                                  14856.5376
# ...

# %%
titanic.sum(numeric_only=True)
# Out:
# PassengerId    460009.0000
# Survived          152.0000
# Pclass            947.0000
# Age             10050.5000
# SibSp             187.0000
# Parch             164.0000
# Fare            14856.5376
# dtype: float64

# %%
states = pd.read_csv("2019_Census_US_Population_Data_By_State_Lat_Long.csv",)

# %%
states.tail(50).head(51).sum(numeric_only=True)
# Out:
# POPESTIMATE2019    3.233363e+08
# lat                1.977189e+03
# long              -4.664033e+03
# dtype: float64

# %%
titanic.count()
# Out:
# PassengerId    418
# Survived       418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
netflix=pd.read_csv("./netflix_titles.csv", sep="|",index_col=0)

# %%
netflix.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
titanic.mean()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_1079/929819788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean()
# PassengerId    1100.500000
# Survived          0.363636
# Pclass            2.265550
# Age              30.272590
# SibSp             0.447368
# Parch             0.392344
# Fare             35.627188
# dtype: float64

# %%
titanic.median()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_1079/502188208.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.median()
# PassengerId    1100.5000
# Survived          0.0000
# Pclass            3.0000
# Age              27.0000
# SibSp             0.0000
# Parch             0.0000
# Fare             14.4542
# dtype: float64

# %%
titanic.mode(numeric_only=True)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# 0            892       0.0     3.0  21.0    0.0    0.0  7.75
# 1            893       NaN     NaN  24.0    NaN    NaN   NaN
# 2            894       NaN     NaN   NaN    NaN    NaN   NaN
# 3            895       NaN     NaN   NaN    NaN    NaN   NaN
# 4            896       NaN     NaN   NaN    NaN    NaN   NaN
# 5            897       NaN     NaN   NaN    NaN    NaN   NaN
# 6            898       NaN     NaN   NaN    NaN    NaN   NaN
# ..           ...       ...     ...   ...    ...    ...   ...
# 411         1303       NaN     NaN   NaN    NaN    NaN   NaN
# 412         1304       NaN     NaN   NaN    NaN    NaN   NaN
# 413         1305       NaN     NaN   NaN    NaN    NaN   NaN
# 414         1306       NaN     NaN   NaN    NaN    NaN   NaN
# 415         1307       NaN     NaN   NaN    NaN    NaN   NaN
# 416         1308       NaN     NaN   NaN    NaN    NaN   NaN
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
type (houses.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.describe(include=["object","int64"])
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#              SibSp       Parch    Ticket            Cabin Embarked
# count   418.000000  418.000000       418               91      418
# ...

# %%
netflix.describe(include="O")
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# # Working with Columns & series

# %%
titanic.Name
# Out:
# 0                                     Kelly, Mr. James
# 1                     Wilkes, Mrs. James (Ellen Needs)
# 2                            Myles, Mr. Thomas Francis
# 3                                     Wirz, Mr. Albert
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                           Svensson, Mr. Johan Cervin
# 6                                 Connolly, Miss. Kate
#                             ...
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412                     Henriksson, Miss. Jenny Lovisa
# 413                                 Spector, Mr. Woolf
# 414                       Oliva y Ocana, Dona. Fermina
# 415                       Saether, Mr. Simon Sivertsen
# 416                                Ware, Mr. Frederick
# 417                           Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
titanic['Name']
# Out:
# 0                                     Kelly, Mr. James
# 1                     Wilkes, Mrs. James (Ellen Needs)
# 2                            Myles, Mr. Thomas Francis
# 3                                     Wirz, Mr. Albert
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                           Svensson, Mr. Johan Cervin
# 6                                 Connolly, Miss. Kate
#                             ...
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412                     Henriksson, Miss. Jenny Lovisa
# 413                                 Spector, Mr. Woolf
# 414                       Oliva y Ocana, Dona. Fermina
# 415                       Saether, Mr. Simon Sivertsen
# 416                                Ware, Mr. Frederick
# 417                           Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
titanic.Age
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
#        ...
# 411    37.0
# 412    28.0
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
titanic['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
#        ...
# 411    37.0
# 412    28.0
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
titanic["Embarked"]
# Out:
# 0      Q
# 1      S
# 2      Q
# 3      S
# 4      S
# 5      S
# 6      Q
#       ..
# 411    Q
# 412    S
# 413    S
# 414    C
# 415    S
# 416    S
# 417    C
# Name: Embarked, Length: 418, dtype: object

# %%
mystery_col = "price"

# %%
houses[mystery_col]
# Out:
# 0         221900.0
# 1         538000.0
# 2         180000.0
# 3         604000.0
# 4         510000.0
# 5        1225000.0
# 6         257500.0
#            ...
# 21606    1007500.0
# 21607     475000.0
# 21608     360000.0
# 21609     400000.0
# 21610     402101.0
# 21611     400000.0
# 21612     325000.0
# Name: price, Length: 21613, dtype: float64

# %%
names = titanic.Name
type(names)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### one dimensional ndarray with axis labels : Series

# %%
names
# Out:
# 0                                     Kelly, Mr. James
# 1                     Wilkes, Mrs. James (Ellen Needs)
# 2                            Myles, Mr. Thomas Francis
# 3                                     Wirz, Mr. Albert
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                           Svensson, Mr. Johan Cervin
# 6                                 Connolly, Miss. Kate
#                             ...
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412                     Henriksson, Miss. Jenny Lovisa
# 413                                 Spector, Mr. Woolf
# 414                       Oliva y Ocana, Dona. Fermina
# 415                       Saether, Mr. Simon Sivertsen
# 416                                Ware, Mr. Frederick
# 417                           Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
houses.mean()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_1079/686991280.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   houses.mean()
# id               4.580302e+09
# price            5.400881e+05
# bedrooms         3.370842e+00
# bathrooms        2.114757e+00
# sqft_living      2.079900e+03
# sqft_lot         1.510697e+04
# floors           1.494309e+00
# waterfront       7.541757e-03
# view             2.343034e-01
# condition        3.409430e+00
# grade            7.656873e+00
# sqft_above       1.788396e+03
# sqft_basement    2.915090e+02
# yr_built         1.971005e+03
# yr_renovated     8.440226e+01
# zipcode          9.807794e+04
# lat              4.756005e+01
# long            -1.222139e+02
# sqft_living15    1.986552e+03
# sqft_lot15       1.276846e+04
# dtype: float64

# %%
houses.price.sum()
# Out:
# 11672925008.0

# %%
houses.price.max()
# Out:
# 7700000.0

# %%
names.shape
# Out:
# (418,)

# %%
titanic.shape
# Out:
# (418, 12)

# %%
names.values
# Out:
# array(['Kelly, Mr. James', 'Wilkes, Mrs. James (Ellen Needs)',
#        'Myles, Mr. Thomas Francis', 'Wirz, Mr. Albert',
#        'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#        'Svensson, Mr. Johan Cervin', 'Connolly, Miss. Kate',
#        'Caldwell, Mr. Albert Francis',
#        'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#        'Davies, Mr. John Samuel', 'Ilieff, Mr. Ylio',
#        'Jones, Mr. Charles Cresson',
#        'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#        'Howard, Mr. Benjamin',
#        'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#        'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#        'Keane, Mr. Daniel', 'Assaf, Mr. Gerios',
#        'Ilmakangas, Miss. Ida Livija',
#        'Assaf Khalil, Mrs. Mariana (Miriam")"', 'Rothschild, Mr. Martin',
#        'Olsen, Master. Artur Karl',
#        'Flegenheim, Mrs. Alfred (Antoinette)',
#        'Williams, Mr. Richard Norris II',
# ...

# %%
names.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
names
# Out:
# 0                                     Kelly, Mr. James
# 1                     Wilkes, Mrs. James (Ellen Needs)
# 2                            Myles, Mr. Thomas Francis
# 3                                     Wirz, Mr. Albert
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                           Svensson, Mr. Johan Cervin
# 6                                 Connolly, Miss. Kate
#                             ...
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412                     Henriksson, Miss. Jenny Lovisa
# 413                                 Spector, Mr. Woolf
# 414                       Oliva y Ocana, Dona. Fermina
# 415                       Saether, Mr. Simon Sivertsen
# 416                                Ware, Mr. Frederick
# 417                           Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
houses.min(numeric_only=True)
# Out:
# id               1.000102e+06
# price            7.500000e+04
# bedrooms         0.000000e+00
# bathrooms        0.000000e+00
# sqft_living      2.900000e+02
# sqft_lot         5.200000e+02
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        1.000000e+00
# grade            1.000000e+00
# sqft_above       2.900000e+02
# sqft_basement    0.000000e+00
# yr_built         1.900000e+03
# yr_renovated     0.000000e+00
# zipcode          9.800100e+04
# lat              4.715590e+01
# long            -1.225190e+02
# sqft_living15    3.990000e+02
# sqft_lot15       6.510000e+02
# dtype: float64

# %%
mins = houses.min(numeric_only=True)

# %%
mins.index
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
mins
# Out:
# id               1.000102e+06
# price            7.500000e+04
# bedrooms         0.000000e+00
# bathrooms        0.000000e+00
# sqft_living      2.900000e+02
# sqft_lot         5.200000e+02
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        1.000000e+00
# grade            1.000000e+00
# sqft_above       2.900000e+02
# sqft_basement    0.000000e+00
# yr_built         1.900000e+03
# yr_renovated     0.000000e+00
# zipcode          9.800100e+04
# lat              4.715590e+01
# long            -1.225190e+02
# sqft_living15    3.990000e+02
# sqft_lot15       6.510000e+02
# dtype: float64

# %% [markdown]
# # Important Series Methods
# * head()
# * tail()
# * describe()
# * unique()
# * nunique()
# * nlargest()
# * nsmallest()
# * value_counts()
# * plot() YAY!

# %%
titanic.Age.head(10)
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# 5    14.0
# 6    30.0
# 7    26.0
# 8    18.0
# 9    21.0
# Name: Age, dtype: float64

# %%
netflix.title.tail(50)
# Out:
# 8757                 World Trade Center
# 8758             World's Busiest Cities
# 8759             World's Weirdest Homes
# 8760                   Would You Rather
# 8761                          Wrong No.
# 8762                    Wrong Side Raju
# 8763    WWII: Report from the Aleutians
# 8764                         Wyatt Earp
# 8765                                 XX
# 8766                                XXx
# 8767            XXX: State of the Union
# 8768                  Y Tu Mamá También
# 8769             Y.M.I.: Yeh Mera India
# 8770                            Yaadein
# 8771                   Yaara O Dildaara
# 8772              Yamla Pagla Deewana 2
# 8773                Yanda Kartavya Aahe
# 8774                          يوم الدين
# 8775                    Yeh Meri Family
# 8776                         Yellowbird
# 8777                          Yes or No
# 8778                        Yes or No 2
# 8779                      Yes or No 2.5
# ...

# %%
houses.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
houses["price"].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
netflix["rating"].describe()
# Out:
# count      8803
# unique       17
# top       TV-MA
# freq       3207
# Name: rating, dtype: object

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.release_year.describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
titanic.Name.dtype
# Out:
# dtype('O')

# %%
houses["bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
netflix["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix["rating"]
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
# 5       TV-MA
# 6          PG
#         ...
# 8800    TV-PG
# 8801    TV-MA
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
netflix["rating"].nunique()
# Out:
# 17

# %%
houses.zipcode.nunique()
# Out:
# 70

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
netflix["rating"].nunique(dropna=False)
# Out:
# 18

# %%
netflix["rating"].nunique()
# Out:
# 17

# %%
houses.price.nlargest(9)
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# 1315    5300000.0
# 1164    5110800.0
# 8092    4668000.0
# 2626    4500000.0
# Name: price, dtype: float64

# %%
houses.price.nsmallest(10)
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# 2141     82500.0
# 18468    83000.0
# 3767     84000.0
# 10253    85000.0
# 16714    85000.0
# Name: price, dtype: float64

# %%
titanic.Pclass.nlargest(4,keep="all")
# Out:
# 0      3
# 1      3
# 3      3
# 4      3
# 5      3
# 6      3
# 8      3
#       ..
# 409    3
# 410    3
# 412    3
# 413    3
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 218, dtype: int64

# %%
houses.nlargest(10,"price")
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13      8570.0
# 3914        10040     37325     2.0           1     2  ...     11      7680.0
# ...

# %%
houses.nsmallest(10,"bedrooms")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 875    6306400140  20140612T000000  1095000.0         0        0.0
# 3119   3918400017  20150205T000000   380000.0         0        0.0
# 3467   1453602309  20140805T000000   288000.0         0        1.5
# 4868   6896300380  20141002T000000   228000.0         0        1.0
# 6994   2954400190  20140624T000000  1295650.0         0        0.0
# 8477   2569500210  20141117T000000   339950.0         0        2.5
# 8484   2310060040  20140925T000000   240000.0         0        2.5
# 9773   3374500520  20150429T000000   355000.0         0        0.0
# 9854   7849202190  20141223T000000   235000.0         0        0.0
# 12653  7849202299  20150218T000000   320000.0         0        2.5
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 875           3064      4764     3.5           0     2  ...      7
# 3119          1470       979     3.0           0     2  ...      8
# ...

# %%
houses.nlargest(10,["bedrooms","bathrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nlargest(10,["sqft_lot"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1719   1020069017  20150327T000000   700000.0         4       1.00
# 17319  3326079016  20150504T000000   190000.0         2       1.00
# 7647   2623069031  20140521T000000   542500.0         5       3.25
# 7769   2323089009  20150119T000000   855000.0         4       3.50
# 3949    722069232  20140905T000000   998000.0         4       3.25
# 4441   3626079040  20140730T000000   790000.0         2       3.00
# 6691   2624089007  20150320T000000  1998000.0         2       2.50
# 7077   2724079090  20150105T000000  1650000.0         4       3.25
# 9714    225079036  20150107T000000   937500.0         4       4.00
# 20452  1125079111  20150415T000000  1600000.0         4       5.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1719          1300   1651359     1.0           0     3  ...      6
# 17319          710   1164794     1.0           0     0  ...      5
# ...

# %%
netflix[["title","rating"]].tail(10)
# Out:
#                    title rating
# 8797           Zak Storm  TV-Y7
# 8798            Zed Plus  TV-MA
# 8799               Zenda  TV-14
# 8800  Zindagi Gulzar Hai  TV-PG
# 8801             Zinzana  TV-MA
# 8802              Zodiac      R
# 8803         Zombie Dumb  TV-Y7
# 8804          Zombieland      R
# 8805                Zoom     PG
# 8806              Zubaan  TV-14

# %%
houses[["price","bedrooms","bathrooms"]].describe()
# Out:
#               price      bedrooms     bathrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757
# std    3.671272e+05      0.930062      0.770163
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000
# 50%    4.500000e+05      3.000000      2.250000
# 75%    6.450000e+05      4.000000      2.500000
# max    7.700000e+06     33.000000      8.000000

# %%
cols = ["price","zipcode","sqft_lot"]
houses[cols]
# Out:
#            price  zipcode  sqft_lot
# 0       221900.0    98178      5650
# 1       538000.0    98125      7242
# 2       180000.0    98028     10000
# 3       604000.0    98136      5000
# 4       510000.0    98074      8080
# 5      1225000.0    98053    101930
# 6       257500.0    98003      6819
# ...          ...      ...       ...
# 21606  1007500.0    98136      7200
# 21607   475000.0    98116      1294
# 21608   360000.0    98103      1131
# 21609   400000.0    98146      5813
# 21610   402101.0    98144      1350
# 21611   400000.0    98027      2388
# 21612   325000.0    98144      1076
#
# [21613 rows x 3 columns]

# %% [markdown]
# ## SERIES.Value_counts
# ### Value_counts return a series containing counts of unique values.

# %%
house["bedrooms"]
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
# 5        4
# 6        3
#         ..
# 21606    4
# 21607    3
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses["bedrooms"].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
titanic.Sex.value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
netflix.director.value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
netflix.director.value_counts(ascending=True).head(10)
# Out:
# Kirsten Johnson                  1
# Evgeny Afineevsky                1
# Kristina Goolsby, Ashley York    1
# Phil Joanou                      1
# Anthony Pierce                   1
# Jennifer Phang                   1
# Jill Bauer, Ronna Gradus         1
# Mike Fleiss                      1
# Aziz Ansari                      1
# David Sampliner                  1
# Name: director, dtype: int64

# %%
houses["floors"].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
houses[["bedrooms","bathrooms"]]
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# 5             4       4.50
# 6             3       2.25
# ...         ...        ...
# 21606         4       3.50
# 21607         3       2.50
# 21608         3       2.50
# 21609         4       2.50
# 21610         2       0.75
# 21611         3       2.50
# 21612         2       0.75
#
# [21613 rows x 2 columns]

# %%
houses[["bedrooms","bathrooms"]].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
# 3         2.25         1082
#           2.00         1048
#                        ...
# 6         7.75            1
#           8.00            1
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Length: 144, dtype: int64

# %%
type(houses[["bedrooms","bathrooms"]].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## SERIES.Plot
# ### plot: make plot of series or dataframe.
# ### Uses the backend by the option plotting.backend. By default, matplotlib is used.

# %%
# %pip install matplotlib
import matplotlib.pyplot as plot
plot.show()
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/nkemakolamnnadi/.pyenv/versions/3.9.10/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
houses.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
# 5        4
# 6        3
#         ..
# 21606    4
# 21607    3
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses.bedrooms.plot()
# Out:
# <Axes: >

# %%
houses.bedrooms.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='bedrooms'>

# %%
titanic.Survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Survived'>

# %%
titanic.Sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Sex'>

# %%
houses.plot()
# Out:
# <Axes: >

# %%
houses[["bedrooms","bathrooms"]].plot()
# Out:
# <Axes: >

# %%
df = houses[["bedrooms","bathrooms"]]
df.plot(kind="scatter", x="bedrooms",y="bathrooms")
# Out:
# /Users/nkemakolamnnadi/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
netflix.rating.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >
