# %%
 45*7/2+2
# Out:
# 159.5

# %%
"ha"* 50
# Out:
# 'hahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahaha'

# %%
2+2+5
# Out:
# 9

# %%
color= "teal"
73*4
1+3
# Out:
# 4

# %%
color
# Out:
# 'teal'

# %% [markdown]
# # Notebook basics
# ## level 2 heading
# - bullet 1
# - bullet 2

# %%
4+5+6
# Out:
# 15

# %%
chicken = "nuggets"

# %%
chicken + "animal"
# Out:
# 'nuggetsanimal'

# %%
import statistics

# %%
statistics
# Out:
# <module 'statistics' from '/Users/nkemakolamnnadi/.pyenv/versions/3.9.10/lib/python3.9/statistics.py'>

# %% [markdown]
# # Exercise 01

# %%
u = "cnrt!yuddi!"
I = 'ogas o i t!'
"".join(i + j for i, j in zip(u, I))
# Out:
# 'congrats! you did it!!'

# %%
# Replace <LYDIA> with your name
"wow, LYDIA is the most amazing person on the planet!"
# Out:
# 'wow, LYDIA is the most amazing person on the planet!'

# %%
print("chicken nuggets")
# Out:
# chicken nuggets

# %%
number = 69

# %%
number * number
# Out:
# 4761

# %%
# Make this cell a python cell and run it ()
"supercalfragilisticexpialidocious" * 20
# Out:
# '...'

# %%
chicken = "nuggets"

# %%
# this cell is supposed to print the integers from 9 down to 1 
# 1. Run this cell which results in an INFINITE LOOP
# 2. Interrupt the Infinite Loop
# 3. Fix the code so that it prints the integers from 9 down to 1 and run it again

number = 10
while number > 1:
    number-=1
    print(number)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # Excercise 02

# %%
import pandas as pd

# %%
bestsellers=pd.read_csv ("bestsellers with categories.csv.xls")

# %%
bestsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
bestsellers.columns, bestsellers.shape
# Out:
# (Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object'),
#  (550, 7))

# %%
bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
bestsellers.head(19)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
bestsellers.tail(5)
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
bestsellers.tail(2)
# Out:
#                                                   Name       Author  \
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
bestsellers.columns == "NULL"
# Out:
# array([False, False, False, False, False, False, False])

# %%
type('User Rating')
# Out:
# str

# %%
bestsellers.columns.shape
# Out:
# (7,)

# %%
everest=pd.read_csv("Mount_everest_death.csv")

# %%
everest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No.             310 non-null    int64
#  1   Name            310 non-null    object
#  2   Date            310 non-null    object
#  3   Age             160 non-null    float64
#  4   Expedition      271 non-null    object
#  5   Nationality     309 non-null    object
#  6   Cause of death  296 non-null    object
#  7   Location        291 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 19.5+ KB

# %%
labels= ["id", "title", "year", "imdb_rating", "imdb_id", "genres"]
movies=pd.read_csv("./movie_titles_metadata.tsv", sep="\t", names=labels)
movies
# Out:
#        id                       title  year  imdb_rating   imdb_id  \
# 0      m0  10 things i hate about you  1999          6.9   62847.0
# 1      m1  1492: conquest of paradise  1992          6.2   10421.0
# 2      m2                  15 minutes  2001          6.1   25854.0
# 3      m3       2001: a space odyssey  1968          8.4  163227.0
# 4      m4                     48 hrs.  1982          6.9   22289.0
# ..    ...                         ...   ...          ...       ...
# 612  m612                    watchmen  2009          7.8  135229.0
# 613  m613                         xxx  2002          5.6   53505.0
# 614  m614                       x-men  2000          7.4  122149.0
# 615  m615          young frankenstein  1974          8.0   57618.0
# 616  m616                   zulu dawn  1979          6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %%
movies.tail(7)
# Out:
#        id                    title  year  imdb_rating   imdb_id  \
# 610  m610         the wizard of oz  1939          8.3  104873.0
# 611  m611  the world is not enough  1999          6.3   60047.0
# 612  m612                 watchmen  2009          7.8  135229.0
# 613  m613                      xxx  2002          5.6   53505.0
# 614  m614                    x-men  2000          7.4  122149.0
# 615  m615       young frankenstein  1974          8.0   57618.0
# 616  m616                zulu dawn  1979          6.4    1911.0
#
#                                                 genres
# 610         ['adventure' 'family' 'fantasy' 'musical']
# 611                  ['action' 'adventure' 'thriller']
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']

# %% [markdown]
# # Exercise 03

# %%
import pandas as pd

# %%
bestsellers=pd.read_csv ("bestsellers with categories.csv.xls")

# %%
bestsellers.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
bestsellers.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %%
bestsellers.mean()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_73545/1813816453.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bestsellers.mean()
# User Rating        4.618364
# Reviews        11953.281818
# Price             13.100000
# Year            2014.000000
# dtype: float64

# %%
bestsellers.head().mean()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_73545/3031482697.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bestsellers.head().mean()
# User Rating        4.7
# Reviews        13494.0
# Price             12.6
# Year            2016.2
# dtype: float64

# %%
bestsellers.mode()
# Out:
#                                                  Name       Author  \
# 0   Publication Manual of the American Psychologic...  Jeff Kinney
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
#
#     User Rating  Reviews  Price  Year        Genre
# 0           4.8   8580.0    8.0  2009  Non Fiction
# 1           NaN      NaN    NaN  2010          NaN
# ...

# %%
bestsellers.sum()
# Out:
# Name           10-Day Green Smoothie Cleanse11/22/63: A Novel...
# Author         JJ SmithStephen KingJordan B. PetersonGeorge O...
# User Rating                                               2540.1
# Reviews                                                  6574305
# Price                                                       7205
# Year                                                     1107700
# Genre          Non FictionFictionNon FictionFictionNon Fictio...
# dtype: object

# %%
bestsellers.describe(include="O")
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310

# %% [markdown]
# # Exercise 04
# ## series and plotting

# %%
bestsellers.Name
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
bestsellers["User Rating"]
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Name: User Rating, Length: 550, dtype: float64

# %%
bestsellers.Author.head(8)
# Out:
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# 5         George R. R. Martin
# 6         George R. R. Martin
# 7                 Amor Towles
# Name: Author, dtype: object

# %%
bestsellers["Genre"].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %%
pd.Series(bestsellers.Author.unique()).describe()
# Out:
# count          248
# unique         248
# top       JJ Smith
# freq             1
# dtype: object

# %%
bestsellers.Author.nunique()
# Out:
# 248

# %%
bestsellers["Price"].mean()
# Out:
# 13.1

# %%
bestsellers.Price.nlargest(10)
# Out:
# 69     105
# 70     105
# 473     82
# 151     54
# 346     53
# 159     52
# 271     46
# 272     46
# 273     46
# 274     46
# Name: Price, dtype: int64

# %%
bestsellers["Name"].value_counts()
# Out:
# Publication Manual of the American Psychological Association, 6th Edition       10
# StrengthsFinder 2.0                                                              9
# Oh, the Places You'll Go!                                                        8
# The Very Hungry Caterpillar                                                      7
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change     7
#                                                                                 ..
# Humans of New York : Stories                                                     1
# Howard Stern Comes Again                                                         1
# Homebody: A Guide to Creating Spaces You Never Want to Leave                     1
# Have a Little Faith: A True Story                                                1
# Night (Night)                                                                    1
# Name: Name, Length: 351, dtype: int64

# %%
bestsellers["Name"].value_counts().head(3)
# Out:
# Publication Manual of the American Psychological Association, 6th Edition    10
# StrengthsFinder 2.0                                                           9
# Oh, the Places You'll Go!                                                     8
# Name: Name, dtype: int64

# %%
bestsellers[["Author", "User Rating"]]
# Out:
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ..                        ...          ...
# 545               Jeff Kinney          4.9
# 546               Jen Sincero          4.7
# 547               Jen Sincero          4.7
# 548               Jen Sincero          4.7
# 549               Jen Sincero          4.7
#
# [550 rows x 2 columns]

# %%
bestsellers[["Author", "User Rating"]].value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Gallup                              4.0             9
# Rick Riordan                        4.8             9
# Dr. Seuss                           4.9             8
#                                                    ..
# Ken Follett                         4.5             1
# Kevin Kwan                          4.3             1
# Khaled Hosseini                     4.3             1
# DK                                  4.5             1
# Jeff Kinney                         4.9             1
# Length: 301, dtype: int64

# %%
bestsellers["Genre"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Genre'>

# %%
bestsellers.Author.value_counts().nlargest(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
bestsellers.Author.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
bestsellers.Author.value_counts().head(10).plot(kind="barh")
# Out:
# <Axes: >

# %%
bestsellers["User Rating"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Exercise 05
# ### Index_Sorting

# %%
import pandas as pd

df = pd.read_csv("DataAnalysis/data/pokemon.csv", index_col=1)

# %%
df
# Out:
#             Num   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1    Grass  Poison    318   45      49       49       65
# Ivysaur       2    Grass  Poison    405   60      62       63       80
# Venusaur      3    Grass  Poison    525   80      82       83      100
# Charmander    4     Fire     NaN    309   39      52       43       60
# Charmeleon    5     Fire     NaN    405   58      64       58       80
# ...         ...      ...     ...    ...  ...     ...      ...      ...
# Dratini     147   Dragon     NaN    300   41      64       45       50
# Dragonair   148   Dragon     NaN    420   61      84       65       70
# Dragonite   149   Dragon  Flying    600   91     134       95      100
# Mewtwo      150  Psychic     NaN    680  106     110       90      154
# Mew         151  Psychic     NaN    600  100     100      100      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# ...

# %%
pokemon = pd.read_csv("DataAnalysis/data/pokemon.csv", index_col=1)

# %%
pokemon.sort_values("Attack", ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Rhydon     112    Ground    Rock    485  105     130      120       45
# Flareon    136      Fire     NaN    525   65     130       60       95
# Machamp     68  Fighting     NaN    505   90     130       80       65
# Kingler     99     Water     NaN    475   55     130      115       50
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Abra        63   Psychic     NaN    310   25      20       15      105
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Chansey    113    Normal     NaN    450  250       5        5       35
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite      100     80      3      False
# ...

# %%
pokemon.sort_values("Num", ascending=True, inplace=True)

# %%
pokemon
# Out:
#             Num   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1    Grass  Poison    318   45      49       49       65
# Ivysaur       2    Grass  Poison    405   60      62       63       80
# Venusaur      3    Grass  Poison    525   80      82       83      100
# Charmander    4     Fire     NaN    309   39      52       43       60
# Charmeleon    5     Fire     NaN    405   58      64       58       80
# ...         ...      ...     ...    ...  ...     ...      ...      ...
# Dratini     147   Dragon     NaN    300   41      64       45       50
# Dragonair   148   Dragon     NaN    420   61      84       65       70
# Dragonite   149   Dragon  Flying    600   91     134       95      100
# Mewtwo      150  Psychic     NaN    680  106     110       90      154
# Mew         151  Psychic     NaN    600  100     100      100      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# ...

# %%
pokemon.sort_values(by=["Total", "Attack"], ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Mewtwo     150   Psychic     NaN    680  106     110       90      154
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Mew        151   Psychic     NaN    600  100     100      100      100
# Moltres    146      Fire  Flying    580   90     100       90      125
# Zapdos     145  Electric  Flying    580   90      90       85      125
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Weedle      13       Bug  Poison    195   40      35       30       20
# Caterpie    10       Bug     NaN    195   45      30       35       20
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Mewtwo          90    130      1       True
# ...

# %%
pokemon.sort_index(inplace=True)

# %%
pokemon
# Out:
#             Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Abra         63   Psychic     NaN    310   25      20       15      105
# Aerodactyl  142      Rock  Flying    515   80     105       65       60
# Alakazam     65   Psychic     NaN    500   55      50       45      135
# Arbok        24    Poison     NaN    438   60      85       69       65
# Arcanine     59      Fire     NaN    555   90     110       80      100
# ...         ...       ...     ...    ...  ...     ...      ...      ...
# Weepinbell   70     Grass  Poison    390   65      90       50       85
# Weezing     110    Poison     NaN    490   65      90      120       85
# Wigglytuff   40    Normal   Fairy    435  140      70       45       85
# Zapdos      145  Electric  Flying    580   90      90       85      125
# Zubat        41    Poison  Flying    245   40      45       35       30
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# ...

# %%
pokemon.nlargest(10, "Speed").mean()
# Out:
# /var/folders/7n/3mgkyzq528j2_2y5kzmw7h_40000gn/T/ipykernel_73545/1907833667.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon.nlargest(10, "Speed").mean()
# Num           93.8
# Total        505.0
# HP            64.6
# Attack        76.0
# Defense       64.0
# Sp. Atk       97.4
# Sp. Def       81.0
# Speed        122.0
# Stage          2.0
# Legendary      0.1
# dtype: float64

# %%
pokemon["Speed"].nlargest(10).mean()
# Out:
# 122.0

# %%
pokemon.sort_values("Speed", ascending=False)["Speed"].head(10).mean()
# Out:
# 122.0

# %%
pokemon[["Attack", "Type 1"]].value_counts().head(10)
# Out:
# Attack  Type 1
# 65      Water       5
# 45      Normal      3
# 60      Normal      3
# 70      Water       2
# 80      Fighting    2
# 70      Normal      2
# 80      Ground      2
#         Poison      2
#         Rock        2
# 90      Electric    2
# dtype: int64

# %%
pokemon.sort_values("Attack").tail(20)["Type 1"].mode()
# Out:
# 0    Fighting
# Name: Type 1, dtype: object

# %%
pokemon.loc[['Diglett']]
# Out:
#          Num  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Diglett   50  Ground    NaN    265  10      55       25       35       45
#
#          Speed  Stage  Legendary
# Name
# Diglett     95      1      False

# %%
pokemon.loc[['Eevee', 'Vulpix']]
# Out:
#         Num  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Eevee   133  Normal    NaN    325  55      55       50       45       65
# Vulpix   37    Fire    NaN    299  38      41       40       50       65
#
#         Speed  Stage  Legendary
# Name
# Eevee      55      1      False
# Vulpix     65      1      False

# %%
pokemon.loc['Charizard':'Charmeleon']
# Out:
#             Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Charizard     6   Fire  Flying    534  78      84       78      109       85
# Charmander    4   Fire     NaN    309  39      52       43       60       50
# Charmeleon    5   Fire     NaN    405  58      64       58       80       65
#
#             Speed  Stage  Legendary
# Name
# Charizard     100      3      False
# Charmander     65      1      False
# Charmeleon     80      2      False

# %%
pokemon.iloc[[30,40,50]]
# Out:
#           Num  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Eevee     133  Normal     NaN    325  55      55       50       45       65
# Gengar     94   Ghost  Poison    500  60      65       60      130       75
# Gyarados  130   Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Eevee        55      1      False
# Gengar      110      3      False
# Gyarados     81      2      False

# %%
fish_pokemon= pokemon.loc[['Magikarp', 'Goldeen', 'Horsea', 'Seaking', 'Seadra', 'Gyarados']]
fish_pokemon
# Out:
#           Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Magikarp  129  Water     NaN    200  20      10       55       15       20
# Goldeen   118  Water     NaN    320  45      67       60       35       50
# Horsea    116  Water     NaN    295  30      40       70       70       25
# Seaking   119  Water     NaN    450  80      92       65       65       80
# Seadra    117  Water     NaN    440  55      65       95       95       45
# Gyarados  130  Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Magikarp     80      1      False
# Goldeen      63      1      False
# Horsea       60      1      False
# Seaking      68      2      False
# Seadra       85      2      False
# Gyarados     81      2      False

# %%
fish_pokemon.Attack.sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# # Exercise 6
# ### Filtering

# %%
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
bestsellers[bestsellers.Author == "Pete Souza"]
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %%
bestsellers[bestsellers["Price"] < 10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
bestsellers[bestsellers["Price"].between(50, 60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
bestsellers[(bestsellers["Price"] > 50) & (bestsellers["Price"] < 60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
kris = bestsellers["Author"] == "Kristin Hannah"
andy = bestsellers["Author"] == "Andy Weir"
deli = bestsellers["Author"] == "Delia Owens"
bestsellers[(kris | andy | deli)]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %%
bestsellers[(bestsellers["Genre"] == "Non Fiction") & (bestsellers["User Rating"] == 4.9)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
bestsellers[bestsellers["Genre"] == "Fiction"].sort_values("User Rating")
# Out:
#                                                   Name           Author  \
# 353                                 The Casual Vacancy     J.K. Rowling
# 132                         Go Set a Watchman: A Novel       Harper Lee
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...      Donna Tartt
# ..                                                 ...              ...
# 41            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.
# 40            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.
# 476                        The Very Hungry Caterpillar       Eric Carle
# 478                        The Very Hungry Caterpillar       Eric Carle
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# 353          3.3     9372     12  2012  Fiction
# ...

# %%
df = bestsellers[(bestsellers["Year"] == 2012) & (bestsellers["Genre"] == "Fiction")]
df.sort_values("Reviews", ascending=False).head()
# Out:
#                                                   Name           Author  \
# 135                                          Gone Girl    Gillian Flynn
# 365                             The Fault in Our Stars       John Green
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 409                          The Hunger Games (Book 1)  Suzanne Collins
# 238                      Mockingjay (The Hunger Games)  Suzanne Collins
#
#      User Rating  Reviews  Price  Year    Genre
# 135          4.0    57271     10  2012  Fiction
# 365          4.7    50482     13  2012  Fiction
# 106          3.8    47265     14  2012  Fiction
# 409          4.7    32122      8  2012  Fiction
# 238          4.5    26741      8  2012  Fiction

# %%
low_rating = bestsellers[bestsellers["User Rating"] < 4.5]
low_rating["Author"].value_counts().head().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # Exercise 07
# ### Adding & Removing Columns

# %%
import pandas as pd
tweets = pd.read_csv("DataAnalysis/data/JoeBidenTweets.csv")

# %%
tweets = pd.read_csv("DataAnalysis/data/JoeBidenTweets.csv", index_col=0)

# %%
tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
tweets.drop(labels="url", axis=1)
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                  tweet  \
# id
# 361388562            Tune in 11:30 ET tomorrow for a live webcast o...
# 543984392            Iowans, there's a good chance there's a Biden ...
# 189287227321356289   We're excited to announce that @JoeBiden is be...
# 189287350034104320   Campaign staff will run this account to keep y...
# 189339650610036736   News for you this morning: VP Biden will speak...
# ...

# %%
tweets.drop(361388562)
# Out:
#                             timestamp  \
# id
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# 189343279140184065   2012-04-09 13:25
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# 189343279140184065   https://twitter.com/JoeBiden/status/1893432791...
# ...

# %%
tweets["user"] = "Joe Biden"
tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
tweets["ratio"] = tweets["replies"] / tweets["retweets"]
tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
tweets.drop(columns= "ratiio", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [306], in <cell line: 1>()
# ----> 1 tweets.drop(columns= "ratiio", inplace=True)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
tweets.sort_values("ratio", ascending=False).head(10)
# Out:
#                             timestamp  \
# id
# 232971730119950338   2012-08-07 22:49
# 1200882191875465216  2019-11-30 21:00
# 1150774078233387008  2019-07-15 14:28
# 1186989582182694922  2019-10-23 12:55
# 1189327302733238272  2019-10-29 23:45
# 1181979945599455232  2019-10-09 17:09
# 1141149986505330693  2019-06-19 01:05
# 1186830433985748993  2019-10-23 02:23
# 1172309499048165376  2019-09-13 00:42
# 1152313660787908610  2019-07-19 20:26
#
#                                                                    url  \
# id
# 232971730119950338   https://twitter.com/JoeBiden/status/2329717301...
# 1200882191875465216  https://twitter.com/JoeBiden/status/1200882191...
# 1150774078233387008  https://twitter.com/JoeBiden/status/1150774078...
# 1186989582182694922  https://twitter.com/JoeBiden/status/1186989582...
# 1189327302733238272  https://twitter.com/JoeBiden/status/1189327302...
# 1181979945599455232  https://twitter.com/JoeBiden/status/1181979945...
# ...

# %%
tweets["interactions"] = tweets["replies"] + tweets["retweets"] + tweets["quotes"] + tweets["likes"]
tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
tweets.sort_values("interactions", ascending=False).head(8)
# Out:
#                             timestamp  \
# id
# 1311120831032909825  2020-09-30 01:49
# 1253751812194070529  2020-04-24 18:25
# 1317978773707345920  2020-10-19 00:00
# 1318170176660135936  2020-10-19 12:40
# 1312460408192724992  2020-10-03 18:32
# 1314034535890378752  2020-10-08 02:47
# 1314031047013732352  2020-10-08 02:33
# 1307491919384260609  2020-09-20 01:29
#
#                                                                    url  \
# id
# 1311120831032909825  https://twitter.com/JoeBiden/status/1311120831...
# 1253751812194070529  https://twitter.com/JoeBiden/status/1253751812...
# 1317978773707345920  https://twitter.com/JoeBiden/status/1317978773...
# 1318170176660135936  https://twitter.com/JoeBiden/status/1318170176...
# 1312460408192724992  https://twitter.com/JoeBiden/status/1312460408...
# 1314034535890378752  https://twitter.com/JoeBiden/status/1314034535...
# 1314031047013732352  https://twitter.com/JoeBiden/status/1314031047...
# ...

# %% [markdown]
# # Exercise 08
# ### Updating Data

# %%
netflix = pd.read_csv("netflix_titles.csv", sep="|", index_col=0)

# %%
netflix.set_index("show_id", inplace=True)

# %%
netflix.loc[["s2202"], ["director"]] = "Greg Whiteley"
netflix.loc[["s2202"]]
# Out:
#             type          title       director  \
# show_id
# s2202    TV Show  Last Chance U  Greg Whiteley
#
#                                                       cast        country  \
# show_id
# s2202    John Franklin III, DJ Law, Buddy Stephens, Bri...  United States
#
#             date_added  release_year rating   duration   listed_in  \
# show_id
# s2202    July 28, 2020          2020  TV-MA  5 Seasons  Docuseries
#
#                                                description
# show_id
# s2202    In a docuseries set at one of NCAA football's ...

# %%
netflix.loc[["s2881", "s3601"], ["duration"]] = "GONE TOO SOON"
netflix.loc[["s2881", "s3601"]]
# Out:
#             type                    title director  \
# show_id
# s2881    TV Show  I Am Not Okay With This      NaN
# s3601    TV Show                     GLOW      NaN
#
#                                                       cast        country  \
# show_id
# s2881    Sophia Lillis, Wyatt Oleff, Kathleen Rose Perk...  United States
# s3601    Alison Brie, Betty Gilpin, Marc Maron, Britney...  United States
#
#                 date_added  release_year rating       duration  \
# show_id
# s2881    February 26, 2020          2020  TV-MA  GONE TOO SOON
# s3601       August 9, 2019          2019  TV-MA  GONE TOO SOON
#
#                                            listed_in  \
# show_id
# s2881    TV Comedies, TV Dramas, TV Sci-Fi & Fantasy
# s3601                         TV Comedies, TV Dramas
#
#                                                description
# show_id
# s2881    Angsty Syd navigates high school awkwardness, ...
# s3601    In 1980s LA, a crew of misfits reinvent themse...

# %%
netflix.rename(columns={"release_year": "release_yr"}, inplace=True)
netflix.rename({"release_year": "release_yr"}, axis=1)
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.rename(index={"s1907": "s6666"}, inplace=True)
netflix[netflix["title"] == "Evil"]
# Out:
#             type title director  \
# show_id
# s6666    TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s6666    Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release_yr rating  duration  listed_in  \
# show_id
# s6666    October 1, 2020        2019  TV-14  1 Season  TV Dramas
#
#                                                description
# show_id
# s6666    A forensic psychologist partners with a Cathol...

# %%
netflix["rating"].replace(["UR","NR"], ["No Rating", "No Rating"])
# Out:
# show_id
# s1       PG-13
# s2       TV-MA
# s3       TV-MA
# s4       TV-MA
# s5       TV-MA
#          ...
# s8803        R
# s8804    TV-Y7
# s8805        R
# s8806       PG
# s8807    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
favs = ["Young Royals", "Dark", "Big Mouth", "BoJack Horseman", "The Queen's Gambit", "American Vandal", "Russian Doll", "Godless"]
netflix["is_fav"] = "false"
netflix.loc[netflix["title"].isin(favs), "is_fav"] = True

# %%
netflix["is_fav"].value_counts()
# Out:
# false    8799
# True        8
# Name: is_fav, dtype: int64

# %% [markdown]
# ## Exercise 09

# %%
netflix = pd.read_csv("netflix_titles.csv", sep="|", index_col=0)

# %%
netflix["country"].isna().value_counts()
# Out:
# False    7976
# True      831
# Name: country, dtype: int64

# %%
netflix[netflix.country.isna()]
# Out:
#      show_id     type                                title  \
# 2         s3  TV Show                            Ganglands
# 3         s4  TV Show                Jailbirds New Orleans
# 5         s6  TV Show                        Midnight Mass
# 6         s7    Movie     My Little Pony: A New Generation
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...      ...      ...                                  ...
# 8718   s8719    Movie               Westside vs. the World
# 8759   s8760    Movie               World's Weirdest Homes
# 8783   s8784  TV Show                                 Yoko
# 8785   s8786  TV Show                                  YOM
# 8803   s8804  TV Show                          Zombie Dumb
#
#                            director  \
# 2                   Julien Leclercq
# 3                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 10                              NaN
# ...

# %%
netflix[["country", "director", "cast"]].isna().value_counts()
# Out:
# country  director  cast
# False    False     False    5336
#          True      False    1969
#          False     True      415
# True     False     False     364
#          True      False     313
# False    True      True      256
# True     True      True       96
#          False     True       58
# dtype: int64

# %%
netflix[netflix.country.isna() & netflix.director.isna() & netflix.cast.isna()]
# Out:
#      show_id     type                                      title director  \
# 3         s4  TV Show                      Jailbirds New Orleans      NaN
# 10       s11  TV Show        Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show            Crime Stories: India Detectives      NaN
# 74       s75  TV Show  The World's Most Amazing Vacation Rentals      NaN
# 123     s124  TV Show                                  Luv Kushh      NaN
# ...      ...      ...                                        ...      ...
# 7812   s7813  TV Show                           Queens of Comedy      NaN
# 8109   s8110  TV Show                                 Strongland      NaN
# 8199   s8200  TV Show                               The Bachelor      NaN
# 8609   s8610  TV Show                                     Towies      NaN
# 8803   s8804  TV Show                                Zombie Dumb      NaN
#
#      cast country          date_added  release_year rating   duration  \
# ...

# %%
netflix.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
netflix.dropna(axis=1)
# Out:
#      show_id     type                  title  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead          2020
# 1         s2  TV Show          Blood & Water          2021
# 2         s3  TV Show              Ganglands          2021
# 3         s4  TV Show  Jailbirds New Orleans          2021
# 4         s5  TV Show           Kota Factory          2021
# ...      ...      ...                    ...           ...
# 8802   s8803    Movie                 Zodiac          2007
# 8803   s8804  TV Show            Zombie Dumb          2018
# 8804   s8805    Movie             Zombieland          2009
# 8805   s8806    Movie                   Zoom          2006
# 8806   s8807    Movie                 Zubaan          2015
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
netflix[["director", "cast"]].dropna()
# Out:
#                            director  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# ...

# %%
netflix.dropna(subset=["director", "cast"])
# Out:
#      show_id     type                             title  \
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# 8         s9  TV Show     The Great British Baking Show
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# ...

# %%
#failed
netflix["rating"].isna().value_counts()
netflix["rating"].fillna("TV-MA")
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
netflix.loc[netflix["rating"].isna(), "rating"] = "TV-MA"

# %%
mode_country = netflix["country"].mode()[0]
netflix.fillna({"country": mode_country},inplace=True)
netflix.country.isna().value_counts()
# Out:
# False    8807
# Name: country, dtype: int64
